# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import string
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, confusion_matrix
from statistics import mean
from collections import Counter
from copy import deepcopy
import operator
from math import log2
from sklearn.model_selection import train_test_split, KFold

# %matplotlib inline

# %%
df = pd.read_csv('ensemble_data.csv')
df.head()
# Out:
#   type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0    p         x           s         n       t    p               f
# 1    e         x           s         y       t    a               f
# 2    e         b           s         w       t    l               f
# 3    p         x           y         w       t    p               f
# 4    e         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring_number ring_type spore_print_color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
db = []

for i ,r in df.iterrows():
    db.append(r)
# Out:
# [type                        p
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   n
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     u
#  Name: 0, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     g
#  Name: 1, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 2, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     u
#  Name: 3, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           n
#  population                  a
#  habitat                     g
#  Name: 4, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  n
#  habitat                     g
#  Name: 5, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  n
#  habitat                     m
#  Name: 6, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     m
#  Name: 7, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  p
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  v
#  habitat                     g
#  Name: 8, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     m
#  Name: 9, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     g
#  Name: 10, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     m
#  Name: 11, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     g
#  Name: 12, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     u
#  Name: 13, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 f
#  cap_color                   n
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  a
#  habitat                     g
#  Name: 14, dtype: object, type                        e
#  cap_shape                   s
#  cap_surface                 f
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  y
#  habitat                     u
#  Name: 15, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   w
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           n
#  population                  a
#  habitat                     g
#  Name: 16, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   n
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     g
#  Name: 17, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     u
#  Name: 18, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   n
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     u
#  Name: 19, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     m
#  Name: 20, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   n
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     g
#  Name: 21, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     m
#  Name: 22, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 23, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     m
#  Name: 24, dtype: object, type                        p
#  cap_shape                   f
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     g
#  Name: 25, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 26, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 27, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   n
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  y
#  habitat                     u
#  Name: 28, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 t
#  stalk_root                  b
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     d
#  Name: 29, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 30, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     u
#  Name: 31, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 32, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   n
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  p
#  stalk_shape                 e
#  stalk_root                  r
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    y
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  y
#  habitat                     p
#  Name: 33, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     m
#  Name: 34, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 f
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   n
#  gill_color                  w
#  stalk_shape                 t
#  stalk_root                  b
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     d
#  Name: 35, dtype: object, type                        e
#  cap_shape                   s
#  cap_surface                 f
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  v
#  habitat                     u
#  Name: 36, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   n
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     u
#  Name: 37, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 f
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   n
#  gill_color                  p
#  stalk_shape                 t
#  stalk_root                  b
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     d
#  Name: 38, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     m
#  Name: 39, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     g
#  Name: 40, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  r
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    y
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  y
#  habitat                     p
#  Name: 41, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 f
#  cap_color                   n
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  y
#  habitat                     u
#  Name: 42, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  p
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     g
#  Name: 43, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  n
#  habitat                     m
#  Name: 44, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     g
#  Name: 45, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     m
#  Name: 46, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 47, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  r
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    y
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     p
#  Name: 48, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  r
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    y
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     p
#  Name: 49, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   n
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  r
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    y
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     g
#  Name: 50, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     g
#  Name: 51, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 52, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   n
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     u
#  Name: 53, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  v
#  habitat                     u
#  Name: 54, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     m
#  Name: 55, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           n
#  population                  a
#  habitat                     g
#  Name: 56, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     g
#  Name: 57, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  n
#  habitat                     g
#  Name: 58, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   n
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  p
#  stalk_shape                 e
#  stalk_root                  r
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    y
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  y
#  habitat                     p
#  Name: 59, dtype: object, type                        e
#  cap_shape                   s
#  cap_surface                 f
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  v
#  habitat                     u
#  Name: 60, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     m
#  Name: 61, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     m
#  Name: 62, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 63, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     g
#  Name: 64, dtype: object, type                        e
# ...
#  gill_color                  k
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     g
#  Name: 978, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  p
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    f
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  a
#  habitat                     g
#  Name: 979, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   n
#  bruises                     t
#  odor                        n
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  u
#  stalk_shape                 t
#  stalk_root                  b
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      p
#  stalk_color_below_ring      p
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  y
#  habitat                     d
#  Name: 980, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  g
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     m
#  Name: 981, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  h
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  s
#  habitat                     g
#  Name: 982, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 f
#  cap_color                   n
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           n
#  population                  s
#  habitat                     g
#  Name: 983, dtype: object, type                        p
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  s
#  habitat                     u
#  Name: 984, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 f
#  cap_color                   w
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    f
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           n
#  population                  s
#  habitat                     g
#  Name: 985, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   w
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    f
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  a
#  habitat                     g
#  Name: 986, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   w
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           n
#  population                  a
#  habitat                     g
#  Name: 987, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  a
#  habitat                     g
#  Name: 988, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     g
#  Name: 989, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  n
#  habitat                     m
#  Name: 990, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   g
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  p
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  a
#  habitat                     g
#  Name: 991, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 s
#  cap_color                   n
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  p
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    f
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           n
#  population                  s
#  habitat                     g
#  Name: 992, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 f
#  cap_color                   n
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  v
#  habitat                     u
#  Name: 993, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 s
#  cap_color                   w
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  k
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  s
#  habitat                     g
#  Name: 994, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 s
#  cap_color                   w
#  bruises                     f
#  odor                        n
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 t
#  stalk_root                  e
#  stalk_surface_above_ring    f
#  stalk_surface_below_ring    f
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   e
#  spore_print_color           k
#  population                  a
#  habitat                     g
#  Name: 995, dtype: object, type                        e
#  cap_shape                   x
#  cap_surface                 y
#  cap_color                   y
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  n
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  s
#  habitat                     m
#  Name: 996, dtype: object, type                        e
#  cap_shape                   f
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        a
#  gill_attachment             f
#  gill_spacing                w
#  gill_size                   n
#  gill_color                  w
#  stalk_shape                 t
#  stalk_root                  b
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           u
#  population                  v
#  habitat                     d
#  Name: 997, dtype: object, type                        e
#  cap_shape                   b
#  cap_surface                 s
#  cap_color                   w
#  bruises                     t
#  odor                        l
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   b
#  gill_color                  w
#  stalk_shape                 e
#  stalk_root                  c
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           n
#  population                  n
#  habitat                     m
#  Name: 998, dtype: object, type                        p
#  cap_shape                   f
#  cap_surface                 y
#  cap_color                   w
#  bruises                     t
#  odor                        p
#  gill_attachment             f
#  gill_spacing                c
#  gill_size                   n
#  gill_color                  p
#  stalk_shape                 e
#  stalk_root                  e
#  stalk_surface_above_ring    s
#  stalk_surface_below_ring    s
#  stalk_color_above_ring      w
#  stalk_color_below_ring      w
#  veil_type                   p
#  veil_color                  w
#  ring_number                 o
#  ring_type                   p
#  spore_print_color           k
#  population                  v
#  habitat                     u
#  Name: 999, dtype: object, ...]

# %%
Y = df.iloc[:, 0].values
X = df
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# %%
header = ['Label', 'Text', 'Length', 'Unigram', 'Bigram', 'Trigram']
class Question:
    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        val = example[self.column]        
        return self.value == val

    def __repr__(self):
        condition = "contains"
        return "Does %s %s %s?" % (
            "Col" + str(self.column), condition, str(self.value))

# %%
def class_counts(rows):
    counts = {}
    for row in rows:
        label = row[0]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
def gini(rows):
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
def info_gain(left, right, current_uncertainty, func=gini):
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * func(left) - (1 - p) * func(right)

# %%
class Leaf:
    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    def __init__(self,
                 question,
                 true_branch,
                 false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def partition(rows, question):
    trueRows = []
    falseRows = []
    
    for r in rows:
        if question.match(r):
            trueRows.append(r)
        else:
            falseRows.append(r)
    
    return trueRows, falseRows

# %%
def findBestSplit(rows, questions, func):   
    best_gain = 0
    best_question = None
    current_uncertainty = func(rows)
    
    for q in questions:
        trueRows, falseRows = partition(rows, q)
        if len(trueRows) == 0 or len(falseRows) == 0:
            continue
        
        gain = info_gain(trueRows, falseRows, current_uncertainty, func)
        
        if gain >= best_gain:
            best_gain, best_question = gain, q
    
    return best_gain, best_question

# %%
def formTree(rows, questions, func):
    gain, question = findBestSplit(rows, questions, func)
       
    if gain == 0:
        return Leaf(rows)
    
    trueRows, falseRows = partition(rows, question)
    questions.remove(question)
    
    trueBranch = formTree(trueRows, questions, func)
    falseBranch = formTree(falseRows, questions, func)
    
    return Decision_Node(question, trueBranch, falseBranch)

# %%
def classifyRow(node, row):
    if isinstance(node, Leaf):
        return node.predictions
    
    if node.question.match(row):
        return classifyRow(node.true_branch, row)
    else:
        return classifyRow(node.false_branch, row)

# %%
def train(data, questions, func):
    return formTree(data, deepcopy(questions), func)

# %%
def classify(root, rows):
    predictions = []
    for r in rows:
        predictions.append(max(classifyRow(root, r).items(), key=operator.itemgetter(1))[0])
    return predictions

# %%
def getDataInIndex(data, index):
    l = []
    for i in range(len(data)):
        if i in index:
            l.append(data[i])
    return l

# %%
def getActualLabels(act_data):
    act_labels = []
    for d in act_data:
        act_labels.append(d[0])
    return act_labels

# %%
def get_unique_vals(X_train, index):
    ans = []
    for i, r in X_train.iterrows():
#         print(r)
        ans.append(r[index])
    
    return set(ans)

# %%
questions = []

for i in range(1, X_train.shape[1]):
    unique_vals = get_unique_vals(X_train,int(i))
    for val in unique_vals:
        questions.append(Question(i,val))

# %%
len(questions)
# Out:
# 117

# %%
db_train = X_train.values.tolist()
db_test = X_test.values.tolist()

# %%
kfold = KFold(5, True, 1)
precision = []
recall = []
f_score = []
i = 0

for trainInd,testInd in kfold.split(db_train):
    train_data = getDataInIndex(db_train, trainInd)
    test_data = getDataInIndex(db_train, testInd)
    
    root = train(train_data, questions, gini)
    
    prediction = classify(root, test_data)
        
    actual = getActualLabels(test_data)
    predicted = prediction
    
    precision.append(precision_score(actual, predicted, average='macro'))
    recall.append(recall_score(actual, predicted, average='macro'))
    f_score.append(f1_score(actual, predicted, average='macro'))
     
    print("Training...")

print("Precision Score = " + str(mean(precision)))
print("Recall Score = " + str(mean(recall)))
print("F Score = " + str(mean(f_score)))
# Out:
# Training...
# Training...
# Training...
# Training...
# Training...
# Precision Score = 0.9997093023255814
# Recall Score = 0.9996742671009772
# F Score = 0.9996913074553999
